# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
import numpy as np
import csv

train_data = np.loadtxt('../datasets/train.csv', delimiter="\t")
test_data = np.loadtxt('../datasets/test.csv', delimiter="\t")

train_X = train_data[:,1:].astype(float)
train_y = train_data[:,0].astype(float)

test_ids = test_data[:,0].astype(int)
test_X = test_data[:,1:].astype(float)

model = Ridge(alpha=0.001)

scaler.fit(train_X)
model.fit(train_X, train_y)

predict_test_y = model.predict(test_X)

for i in range(len(predict_test_y)):
    #with open('result.csv', 'w') as f:
    #    writer = csv.writer(f)
    #    writer.writerow([test_ids[i], predict_test_y[i]])
    print(test_ids[i], predict_test_y[i])
# Out:
# 1 26.501418403226012
# 2 21.133088042855142
# 4 32.175563694488574
# 5 19.66085250412891
# 6 27.747560889374135
# 7 22.630490224257215
# 8 14.860205968517263
# 10 21.111783160351564
# 12 25.42294671483738
# 14 23.589745765297806
# 15 11.057080878267097
# 17 30.956513267730664
# 20 11.653298756968834
# 21 33.40943366834078
# 22 30.26778565566697
# 26 17.512562258510606
# 27 21.381382177279768
# 29 24.218648251529416
# 30 11.165833344777816
# 33 30.412616594356024
# 34 27.168115847599807
# 37 33.27712576800453
# 45 17.29135152295079
# 46 8.834741513302884
# 49 16.713756910658475
# 51 10.397719902858096
# 52 12.694104858602632
# 54 20.117443888221644
# 55 29.234031719260074
# 56 29.587360187794054
# 59 34.74797380173649
# 60 18.863050008684056
# 61 36.601542424322936
# 63 10.083952924833415
# 64 20.74463674689511
# 65 29.111935784475783
# 66 32.78971195485073
# 68 20.662295035890423
# 73 27.94665411378803
# 74 34.65115103385131
# 76 10.577126925337865
# 78 31.105477023946975
# ...
